# %%
import io
from IPython.nbformat import current
def execute_notebook(nbfile):
    with io.open(nbfile) as f:
        nb = current.read(f, 'json')
    ip = get_ipython()
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)
execute_notebook("../../imports/imports.ipynb")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /cellar/users/ramarty/anaconda/lib/python2.7/site-packages/IPython/nbformat/current.py:19: UserWarning: IPython.nbformat.current is deprecated.
#
# - use IPython.nbformat for read/write/validate public API
# - use IPython.nbformat.vX directly to composing notebooks of a particular version
#
#   """)

# %% [markdown]
# Data requirements for all: PBR matrix

# %%
patient_affinities = pd.read_csv('/cellar/users/ramarty/Data/hla/git_data/data/patient_affinities.cancer.PHBR.csv', index_col=0)

# %% [markdown]
# ## Panel A

# %%
ax = (patient_affinities < 4).mean().hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of mutations')
plt.xlabel('Fraction of patients with PBRH < 4')
plt.savefig(PATH_TO_GENERATED_FIGURES + 'clustermap.A.pdf')

# %% [markdown]
# ## Panel B

# %%
ax = (patient_affinities < 1).mean().hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of mutations')
plt.xlabel('Fraction of patients PHBR < 1')
plt.savefig(PATH_TO_GENERATED_FIGURES + 'clustermap.B.pdf')

# %% [markdown]
# ## Panel C

# %%
ax = (patient_affinities < 4).mean(axis=1).hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of patients')
plt.xlabel('Fraction of mutations with PHBR < 4')
plt.savefig(PATH_TO_GENERATED_FIGURES + 'clustermap.C.pdf')

# %% [markdown]
# ## Panel D

# %%
ax = (patient_affinities < 1).mean(axis=1).hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of patients')
plt.xlabel('Fraction of mutations with PHBR < 1')
plt.savefig(PATH_TO_GENERATED_FIGURES + 'clustermap.D.pdf')
