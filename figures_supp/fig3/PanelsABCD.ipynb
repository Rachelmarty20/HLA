# %%
import io
from IPython.nbformat import current
def execute_notebook(nbfile):
    with io.open(nbfile) as f:
        nb = current.read(f, 'json')
    ip = get_ipython()
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)
execute_notebook("../../imports/imports.ipynb")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /cellar/users/ramarty/anaconda/lib/python2.7/site-packages/IPython/nbformat/current.py:19: UserWarning: IPython.nbformat.current is deprecated.
#
# - use IPython.nbformat for read/write/validate public API
# - use IPython.nbformat.vX directly to composing notebooks of a particular version
#
#   """)

# %% [markdown]
# Data requirements for all: PBR matrix

# %%
patient_affinities = pd.read_csv('../../data/patient_affinities.cancer.csv', index_col=0)

# %% [markdown]
# ## Panel A

# %%
ax = (patient_affinities < 2).mean().hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of mutations')
plt.xlabel('Fraction of patients that can weakly (rank < 2%) present')

# %% [markdown]
# ## Panel B

# %%
ax = (patient_affinities < 0.5).mean().hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of mutations')
plt.xlabel('Fraction of patients that can strongly (rank < 0.5%) present')

# %% [markdown]
# ## Panel C

# %%
ax = (patient_affinities < 2).mean(axis=1).hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of patients')
plt.xlabel('Fraction of mutations weakly (rank < 2%) presented')

# %% [markdown]
# ## Panel D

# %%
ax = (patient_affinities < 0.5).mean(axis=1).hist(bins=30, color='w')
ax.grid(False)
plt.ylabel('Number of patients')
plt.xlabel('Fraction of mutations strongly (rank < 0.5%) presented')
