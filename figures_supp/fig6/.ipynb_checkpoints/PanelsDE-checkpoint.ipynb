# %%
import io
from IPython.nbformat import current
def execute_notebook(nbfile):
    with io.open(nbfile) as f:
        nb = current.read(f, 'json')
    ip = get_ipython()
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)
execute_notebook("../../imports/imports.ipynb")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /cellar/users/ramarty/anaconda/lib/python2.7/site-packages/IPython/nbformat/current.py:19: UserWarning: IPython.nbformat.current is deprecated.
#
# - use IPython.nbformat for read/write/validate public API
# - use IPython.nbformat.vX directly to composing notebooks of a particular version
#
#   """)

# %% [markdown]
# ## Panel D <br>
# Data required: uniprot domains, whole gene affinities

# %%
cancer_genes = [x.strip() for x in open('../../data/tumor_suppressor_genes.txt').readlines()] + [x.strip() for x in open('../../data/onco_genes.txt').readlines()]

# %%
df = pd.read_csv('../../data/uniprot_domains.tab', sep='\t')
df.columns = ['Entry', 'Status', 'Length', 'DNA', 'Active', 'Binding', 'Domain_cc', 'Domain_ft', 'gene']
df = df[df.gene.isin(cancer_genes)]
df = df.drop_duplicates('gene')
df = df[['DNA', 'Active', 'Binding', 'Domain_cc', 'Domain_ft', 'gene']]

# %%
in_domain, out_domain = [], []
for row in df.iterrows():
    print row[1]['gene']
    gene = row[1]['gene']
    matrix = pd.read_csv('../../data/gene_affinities/{0}.csv'.format(gene), index_col=0)
    p = matrix.median(axis=1).reset_index()
    p.columns = ['residue', 'score']
    
    try:
        domains = row[1]['Domain_ft']
        domains = [[float(j) for j in y.split()[1:3]] for y in domains.split(';')]
        
        in_residues = []
        for r in domains:
            in_residues.extend(range(int(r[0]), int(r[1]+1)))

        i = p[p.residue.isin(in_residues)].score
        o = p[~p.residue.isin(in_residues)].score
        print sp.mannwhitneyu(i, o)
        in_domain.extend(i)
        out_domain.extend(o)
        
    except:
        print 'no domains'
# Out:
# HLA-A
# MannwhitneyuResult(statistic=9902.0, pvalue=0.0025104349714888483)
# HLA-B
# MannwhitneyuResult(statistic=11119.5, pvalue=0.16062676144394455)
# ACADS
# no domains
# ACVR1B
# MannwhitneyuResult(statistic=30799.0, pvalue=0.0016773953961131912)
# PPP2R1A
# no domains
# MLLT4
# MannwhitneyuResult(statistic=259873.0, pvalue=1.0192196099004076e-24)
# ALK
# MannwhitneyuResult(statistic=255051.5, pvalue=1.3281246020562325e-10)
# GOT2
# no domains
# CDKN2A
# no domains
# GNAS
# no domains
# AKT1
# MannwhitneyuResult(statistic=3933.0, pvalue=1.7612174423790273e-11)
# AOAH
# MannwhitneyuResult(statistic=19220.0, pvalue=0.0022806836902925722)
# AJUBA
# MannwhitneyuResult(statistic=21407.5, pvalue=3.9068552726331591e-12)
# ATRX
# MannwhitneyuResult(statistic=274343.5, pvalue=8.7229834461512048e-57)
# APC
# no domains
# AQP2
# no domains
# ARID2
# MannwhitneyuResult(statistic=31907.5, pvalue=2.859680777603135e-23)
# ARF4
# no domains
# ASXL1
# no domains
# ARID1B
# MannwhitneyuResult(statistic=81121.0, pvalue=0.00065553954741161236)
# ARID1A
# MannwhitneyuResult(statistic=53118.0, pvalue=6.2296903749415813e-15)
# ACVR2A
# MannwhitneyuResult(statistic=26780.5, pvalue=0.00055061771207903874)
# ATM
# MannwhitneyuResult(statistic=955936.5, pvalue=0.3492525249050854)
# B2M
# MannwhitneyuResult(statistic=1215.0, pvalue=0.071764317125268276)
# BCOR
# no domains
# BAP1
# no domains
# BRAF
# MannwhitneyuResult(statistic=45408.0, pvalue=5.6986549047169198e-19)
# CEBPA
# MannwhitneyuResult(statistic=9239.0, pvalue=0.41105699307182275)
# CDH1
# MannwhitneyuResult(statistic=84581.5, pvalue=0.021266032466497983)
# CASP8
# MannwhitneyuResult(statistic=21369.0, pvalue=8.9225252104697885e-08)
# BTBD11
# MannwhitneyuResult(statistic=17149.5, pvalue=1.6750092410398945e-12)
# CDK12
# MannwhitneyuResult(statistic=102476.0, pvalue=5.8558622062098095e-29)
# CAPRIN2
# MannwhitneyuResult(statistic=39617.5, pvalue=6.0367749917163171e-15)
# CCAR1
# MannwhitneyuResult(statistic=18034.0, pvalue=0.22230261712690219)
# CARM1
# MannwhitneyuResult(statistic=36360.5, pvalue=2.6093365044367764e-06)
# CREBBP
# MannwhitneyuResult(statistic=356098.5, pvalue=3.0814578019595327e-26)
# CDKN1A
# no domains
# CHD4
# MannwhitneyuResult(statistic=241165.5, pvalue=1.2161652486687511e-30)
# CHD8
# MannwhitneyuResult(statistic=337901.5, pvalue=7.0254516796593708e-26)
# CDKN1B
# no domains
# COL4A2
# MannwhitneyuResult(statistic=58943.5, pvalue=2.277164205729124e-55)
# COL5A2
# MannwhitneyuResult(statistic=48733.5, pvalue=5.5193464151711037e-83)
# CIC
# no domains
# CSMD3
# MannwhitneyuResult(statistic=673383.0, pvalue=9.5893436929564572e-08)
# DCLK1
# MannwhitneyuResult(statistic=38019.0, pvalue=6.7484787108970624e-24)
# CTNNB1
# no domains
# CRIPAK
# no domains
# CTCF
# no domains
# DDX3X
# MannwhitneyuResult(statistic=24906.0, pvalue=7.7059895709486849e-34)
# DKK2
# no domains
# DNMT3A
# MannwhitneyuResult(statistic=60520.5, pvalue=5.1403059191535414e-28)
# ELF3
# MannwhitneyuResult(statistic=11636.5, pvalue=0.20615938632301523)
# EEF1B2
# MannwhitneyuResult(statistic=4730.0, pvalue=0.0066961245056314147)
# EGFR
# MannwhitneyuResult(statistic=92298.5, pvalue=8.5157091118218147e-12)
# ERBB2
# MannwhitneyuResult(statistic=101780.0, pvalue=3.2239362432026263e-09)
# FAM8A1
# MannwhitneyuResult(statistic=8646.5, pvalue=6.8287970777524499e-24)
# EBPL
# MannwhitneyuResult(statistic=1603.5, pvalue=3.7700957573975365e-13)
# ERBB3
# MannwhitneyuResult(statistic=99673.5, pvalue=3.253324066411221e-13)
# EZH2
# MannwhitneyuResult(statistic=51814.0, pvalue=0.0085468013008181271)
# EP300
# MannwhitneyuResult(statistic=339581.0, pvalue=8.9591283248489225e-30)
# FGFR2
# MannwhitneyuResult(statistic=63040.5, pvalue=0.030202014278019922)
# FUBP1
# MannwhitneyuResult(statistic=45071.5, pvalue=0.00053600428412328043)
# FLT3
# MannwhitneyuResult(statistic=114467.0, pvalue=0.062705364913285627)
# FBXW7
# MannwhitneyuResult(statistic=7270.5, pvalue=5.4296196959214996e-10)
# FAT1
# no domains
# GATA3
# no domains
# GPS2
# no domains
# GRID1
# no domains
# GRXCR1
# MannwhitneyuResult(statistic=7129.0, pvalue=4.4856861210522173e-05)
# GRM5
# no domains
# HGF
# MannwhitneyuResult(statistic=29034.0, pvalue=0.13969960538368997)
# IDH2
# no domains
# TCF12
# MannwhitneyuResult(statistic=11960.5, pvalue=4.3889778177948938e-05)
# KCNQ5
# no domains
# IFITM1
# no domains
# IL32
# no domains
# IDH1
# no domains
# ID3
# MannwhitneyuResult(statistic=785.0, pvalue=1.1715659012901994e-07)
# INTS7
# no domains
# KMT2D
# MannwhitneyuResult(statistic=373898.5, pvalue=1.0966140626632998e-44)
# KRT15
# no domains
# KDM5C
# MannwhitneyuResult(statistic=120593.5, pvalue=7.8370148767381874e-23)
# KMT2B
# MannwhitneyuResult(statistic=148355.5, pvalue=1.2827434528052395e-51)
# KRTAP4-11
# no domains
# KCND3
# no domains
# KDM6A
# MannwhitneyuResult(statistic=84252.5, pvalue=0.00014087934040649724)
# PRKCI
# MannwhitneyuResult(statistic=21861.0, pvalue=1.2636254584019987e-14)
# KEAP1
# MannwhitneyuResult(statistic=24147.5, pvalue=2.230686611052274e-14)
# KANSL1
# no domains
# JAKMIP2
# no domains
# KMT2C
# MannwhitneyuResult(statistic=463874.0, pvalue=3.4175077814879388e-35)
# LARP4B
# MannwhitneyuResult(statistic=30652.5, pvalue=8.1161769557917737e-11)
# LHFPL1
# no domains
# MS4A8
# no domains
# LZTR1
# MannwhitneyuResult(statistic=52520.0, pvalue=0.12802852373971318)
# MBD6
# MannwhitneyuResult(statistic=17670.0, pvalue=2.7683466900248335e-11)
# MED12
# no domains
# ABCB1
# MannwhitneyuResult(statistic=78939.0, pvalue=2.026264413423004e-11)
# MB21D2
# no domains
# LSM11
# no domains
# MAX
# MannwhitneyuResult(statistic=1020.0, pvalue=3.3677318736106453e-11)
# MAGI2
# MannwhitneyuResult(statistic=200193.5, pvalue=5.1094929784278578e-16)
# MAP3K1
# MannwhitneyuResult(statistic=133036.0, pvalue=2.0828219054330685e-07)
# LUM
# MannwhitneyuResult(statistic=4891.5, pvalue=0.050475021438385344)
# MFGE8
# MannwhitneyuResult(statistic=3421.5, pvalue=0.0011192515907681416)
# MAPK1
# MannwhitneyuResult(statistic=8321.0, pvalue=0.0066704411836659028)
# MBOAT2
# no domains
# MEN1
# no domains
# METTL14
# no domains
# MFAP5
# no domains
# MEF2B
# MannwhitneyuResult(statistic=4975.0, pvalue=1.2463189484112782e-07)
# NF2
# MannwhitneyuResult(statistic=27927.5, pvalue=3.3570872810959735e-15)
# MAP2K1
# MannwhitneyuResult(statistic=8368.5, pvalue=1.1693067222492543e-10)
# MYH2
# MannwhitneyuResult(statistic=198231.5, pvalue=1.1269171496922028e-92)
# MTOR
# MannwhitneyuResult(statistic=654164.0, pvalue=3.1463807776508117e-10)
# MYF5
# MannwhitneyuResult(statistic=3637.0, pvalue=0.00026353077863585945)
# MAP2K4
# MannwhitneyuResult(statistic=17073.5, pvalue=0.034551477291981367)
# MYO6
# MannwhitneyuResult(statistic=150435.5, pvalue=1.453029251845281e-15)
# MYCN
# MannwhitneyuResult(statistic=6144.0, pvalue=1.1513809916570554e-07)
# MYD88
# MannwhitneyuResult(statistic=11450.5, pvalue=0.27272372330048511)
# NAA25
# no domains
# NFE2L2
# MannwhitneyuResult(statistic=10723.5, pvalue=3.0220495819297145e-07)
# MYC
# MannwhitneyuResult(statistic=9793.5, pvalue=0.17653799596990016)
# NF1
# MannwhitneyuResult(statistic=413642.0, pvalue=0.00041646977376685293)
# NOTCH2
# no domains
# NOTCH1
# no domains
# NCOR1
# MannwhitneyuResult(statistic=86997.0, pvalue=4.5979777099300069e-07)
# NUTM2F
# no domains
# NPM1
# no domains
# NSMCE1
# no domains
# NSD1
# MannwhitneyuResult(statistic=230573.0, pvalue=4.2159536740880082e-29)
# PDE7B
# no domains
# OR5I1
# no domains
# TP53
# no domains
# PIK3R1
# MannwhitneyuResult(statistic=34238.5, pvalue=2.507551684857716e-25)
# PBRM1
# MannwhitneyuResult(statistic=239710.5, pvalue=5.4331432475691757e-25)
# PLEKHA6
# MannwhitneyuResult(statistic=34490.5, pvalue=1.0642458001907211e-06)
# PLK2
# MannwhitneyuResult(statistic=30076.0, pvalue=3.5772907338487787e-27)
# PHF6
# no domains
# PGM5
# no domains
# PPP6C
# no domains
# PIK3CA
# MannwhitneyuResult(statistic=95458.0, pvalue=0.0042257468774840549)
# PTPN11
# MannwhitneyuResult(statistic=23686.0, pvalue=0.0080226081035468313)
# PTEN
# MannwhitneyuResult(statistic=4161.0, pvalue=1.1942318451384084e-17)
# PTN
# no domains
# RAC1
# no domains
# NRAS
# no domains
# RB1
# no domains
# KRAS
# no domains
# RBM10
# MannwhitneyuResult(statistic=52306.0, pvalue=1.3365246113486317e-12)
# RBMX
# MannwhitneyuResult(statistic=6240.0, pvalue=5.7447049623278301e-12)
# SF3B1
# no domains
# SMAD2
# MannwhitneyuResult(statistic=17789.5, pvalue=0.13538641274991869)
# SMAD4
# MannwhitneyuResult(statistic=30647.0, pvalue=0.0079964028110887896)
# SETD2
# MannwhitneyuResult(statistic=260723.0, pvalue=0.44896630106249769)
# SKAP2
# MannwhitneyuResult(statistic=9602.0, pvalue=2.6783310286355418e-11)
# SOX17
# MannwhitneyuResult(statistic=13574.5, pvalue=2.5973833865298593e-06)
# VHL
# no domains
# WT1
# no domains
# XYLT1
# no domains
# RASA1
# MannwhitneyuResult(statistic=94689.5, pvalue=4.9126278385266687e-14)
# HRAS
# no domains
# RHOA
# no domains
# RERE
# MannwhitneyuResult(statistic=138062.5, pvalue=1.8291313974372442e-21)
# ARHGAP35
# MannwhitneyuResult(statistic=173693.5, pvalue=5.7074150375964161e-13)
# RPL22
# no domains
# RIT1
# no domains
# RNF43
# no domains
# RRAS2
# no domains
# RUNX1
# MannwhitneyuResult(statistic=19464.0, pvalue=0.009103150273544804)
# SMARCB1
# no domains
# SPOP
# MannwhitneyuResult(statistic=12483.0, pvalue=0.0034460341347918254)
# SULT1C4
# no domains
# SMARCA4
# MannwhitneyuResult(statistic=180949.5, pvalue=7.5852614371219828e-38)
# STAG2
# MannwhitneyuResult(statistic=24957.0, pvalue=1.4167177010257118e-15)
# STK11
# MannwhitneyuResult(statistic=15523.0, pvalue=2.624671158215172e-08)
# TAF1
# MannwhitneyuResult(statistic=418166.5, pvalue=0.0022930996542208431)
# ZFP36L1
# no domains
# TBL1XR1
# MannwhitneyuResult(statistic=7878.0, pvalue=8.2038585500714047e-15)
# TET2
# no domains
# TGFBR2
# MannwhitneyuResult(statistic=42808.5, pvalue=0.31746164564539747)
# TBX18
# no domains
# TBX3
# no domains
# ZFP36L2
# no domains
# TRIM23
# no domains
# THRAP3
# no domains
# TRIP12
# MannwhitneyuResult(statistic=156767.5, pvalue=0.0011188606905228639)
# TOR1A
# no domains
# TNRC6B
# MannwhitneyuResult(statistic=28730.5, pvalue=5.2420284157011394e-16)
# TUSC3
# MannwhitneyuResult(statistic=12582.0, pvalue=0.04375172447281523)
# TRIM48
# no domains
# U2AF1
# MannwhitneyuResult(statistic=5075.0, pvalue=0.0023964307065285351)
# USP28
# MannwhitneyuResult(statistic=128612.0, pvalue=0.00086642101123280833)
# UBQLN2
# MannwhitneyuResult(statistic=36270.0, pvalue=1.7196726860493239e-07)
# ZC3H13
# no domains
# ZC3H18
# no domains
# ZNF117
# no domains
# ZNF318
# no domains
# ZNF799
# MannwhitneyuResult(statistic=21551.5, pvalue=0.14234714271838389)
# ZNF844
# MannwhitneyuResult(statistic=18304.0, pvalue=0.00016183025347948221)

# %%
frame = pd.DataFrame({'score': in_domain + out_domain, 'domain': ['in' for x in in_domain] + ['out' for x in out_domain]})

# %%
sns.boxplot(x='domain', y='score', data=frame, showfliers=False, color='white')
plt.ylabel('Average presentation score per patient')
plt.xlabel('Residues in/out of domains')
plt.title('All functional domains')
plt.ylim(0, 6)
# Out:
# (0, 6)

# %% [markdown]
# ## Panel E

# %%
total_residues = len(in_domain) + len(out_domain)
residue_distribution = pd.DataFrame({'Fraction': [float(len(in_domain))/total_residues, float(len(out_domain))/total_residues],
                                     'Category': ['In Domain', 'Out of Domain']})

# %%
sns.barplot(x='Category', y='Fraction', data=residue_distribution, color='white')
